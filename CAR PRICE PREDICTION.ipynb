# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
print("Import is successfull")
# Out:
# Import is successfull

# %%
df = pd.read_csv("car_price_dataset.csv")
df
# Out:
#    Car_Age  Price
# 0        1  20000
# 1        2  18000
# 2        3  16000
# 3        4  14000
# 4        5  12000

# %%
df.rename(columns={'Car_Age': 'Car Age'}, inplace=True)
df
# Out:
#    Car Age  Price
# 0        1  20000
# 1        2  18000
# 2        3  16000
# 3        4  14000
# 4        5  12000

# %% [markdown]
# # DEFINE (X,Y)

# %%
X = df[["Car Age"]] # independent vaiable
y = df["Price"]     # dependent vaiable

# %% [markdown]
# # TRAIN/TEXT SPLIT

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y,
    test_size = 0.2,            # 80,20 train, test split
    random_state = 42
)

# %% [markdown]
# # CREATE MODEL

# %%
model = LinearRegression()

# %% [markdown]
# # TRAIN MODEL

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # MAKE PREDICTION

# %%
y_pred = model.predict(X_test)

print("Predicted prices")
print(y_pred)
# Out:
# Predicted prices
# [18000.]

# %% [markdown]
# # MODEL PARAMETERS

# %%
print("Intercept", model.intercept_)
print("Slope", model.coef_)
# Out:
# Intercept 22000.0
# Slope [-2000.]

# %% [markdown]
# # MODEL EVALUATE

# %%
score = r2_score(y_test, y_pred)

print("R2 Score:", score)
# Out:
# R2 Score: nan
# C:\Users\MIR SHAHADUT HOSSAIN\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_regression.py:1288: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %% [markdown]
# # VISUALIZE REGRESSION LINE

# %%
plt.scatter(X,y)
plt.plot(X, model.predict(X))

plt.xlabel("Car Age")
plt.ylabel("Price")
plt.title("Linear Regression Example")

plt.show()
