# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
print("Import Successfull")
# Out:
# Import Successfull

# %% [markdown]
# # IMPORT DATAFRAME

# %%
df = pd.read_csv("house_price_dataset.csv")
df
# Out:
#    Size_sqft   Price
# 0        600  120000
# 1        800  150000
# 2       1000  180000
# 3       1200  200000
# 4       1500  240000

# %%
df.rename(columns={"Size_sqft": "Size sqft"}, inplace = True)
df
# Out:
#    Size sqft   Price
# 0        600  120000
# 1        800  150000
# 2       1000  180000
# 3       1200  200000
# 4       1500  240000

# %% [markdown]
# # DEFINE (X,Y)

# %%
x = df[["Size sqft"]]       # independent vaiable
y = df['Price']              # dependent variable

# %% [markdown]
# # TRAIN/TEXT SPLIT

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,y,
    test_size = 0.2,
    random_state = 42
)

# %% [markdown]
# # CREATE MODEL

# %%
model = LinearRegression()

# %% [markdown]
# # TRAIN MODEL

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # MAKE PREDICTION

# %%
y_pred = model.predict(x_test)

print("Model Predicted")
print(y_pred)
# Out:
# Model Predicted
# [148654.97076023]

# %% [markdown]
# # MODEL PERAMETERS

# %%
print("Intercept: ", model.intercept_)
print("Slope: ", model.coef_)
# Out:
# Intercept:  42923.976608187106
# Slope:  [132.16374269]

# %% [markdown]
# # MODEL EVALUATE

# %%
score = r2_score(y_test, y_pred)

print("R2 Score: ", score)
# Out:
# R2 Score:  nan
# C:\Users\MIR SHAHADUT HOSSAIN\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_regression.py:1288: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %% [markdown]
# # VISUALIZE REGRESSION LINE

# %%
plt.scatter(x,y)
plt.plot(x, model.predict(x))

plt.xlabel("Size sqft")
plt.ylabel("Price")
plt.title("Linear Regression Example")

plt.show()
